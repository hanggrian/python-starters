# %% [markdown]
# [![Python](https://img.shields.io/badge/python-3-informational)](https://docs.python.org/3/)

# %% [markdown]
# # My Notebook
#
# Some cool stuff going on here.

# %%
from tables import show


show('resources/receipt.csv')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Item</th>
#       <th>Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Apple</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Orange Juice</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Milk</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>Grand Total</th>
#       <td></td>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Usage
#
# Create a virtual environment and install it to an IPython kernel.
#
# ```sh
# ipython kernel install --user --name=.venv
# ```
